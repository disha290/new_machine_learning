# %%
#DecisionTreeClassifier

from sklearn.tree import DecisionTreeClassifier

#Train the Decision Tree
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_resampled, y_resampled)

# Predict
y_pred_dt = dt_model.predict(X_test)

# Accuracy
accuracy_dt = accuracy_score(y_test, y_pred_dt) * 100
print(f"Accuracy (Decision Tree): {accuracy_dt:.2f}%")

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_dt))

# Confusion matrix
cm_dt = confusion_matrix(y_test, y_pred_dt)
sns.heatmap(cm_dt, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix - Decision Tree')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

#Count predictions for Decision Tree
predicted_approved_dt = sum(y_pred_dt == 1)
predicted_not_approved_dt = sum(y_pred_dt == 0)

print(f"\nNumber of applications predicted as Approved (Decision Tree): {predicted_approved_dt}")
print(f"Number of applications predicted as Not Approved (Decision Tree): {predicted_not_approved_dt}")

from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(dt_model, filled=True, feature_names=X.columns, class_names=["Not Approved", "Approved"], max_depth=3)
plt.title("Visualized Decision Tree (Top 3 Levels)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 #Train the Decision Tree
#       6 dt_model = DecisionTreeClassifier(random_state=42)
# ----> 7 dt_model.fit(X_resampled, y_resampled)
#       9 # Predict
#      10 y_pred_dt = dt_model.predict(X_test)
#
# NameError: name 'X_resampled' is not defined

# %%
# RANDOM FOREST CLASSIFIER
from sklearn.ensemble import RandomForestClassifier

# Train Random Forest model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_resampled, y_resampled)

# 🧪 Predict on test data
y_pred_rf = rf_model.predict(X_test)

# Accuracy
accuracy_rf = accuracy_score(y_test, y_pred_rf) * 100
print(f"Accuracy (Random Forest): {accuracy_rf:.2f}%")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))

cm_rf = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Oranges')
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Count predictions
predicted_approved_rf = sum(y_pred_rf == 1)
predicted_not_approved_rf = sum(y_pred_rf == 0)

print(f"\nNumber of applications predicted as Approved (Random Forest): {predicted_approved_rf}")
print(f"Number of applications predicted as Not Approved (Random Forest): {predicted_not_approved_rf}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4 # Train Random Forest model
#       5 rf_model = RandomForestClassifier(random_state=42)
# ----> 6 rf_model.fit(X_resampled, y_resampled)
#       8 # 🧪 Predict on test data
#       9 y_pred_rf = rf_model.predict(X_test)
#
# NameError: name 'X_resampled' is not defined

# %%
# XGBOOST CLASSIFIER
from xgboost import XGBClassifier

# Train XGBoost
model = XGBClassifier(eval_metric='logloss', random_state=42)
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, y_pred) * 100
print(f"Accuracy (XGBoost): {acc:.2f}%")

# Confusion Matrix
cm_xgb = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:\n", cm_xgb)

print("\n Classification Report:\n")
print(classification_report(y_test, y_pred, zero_division=0))

# Count predictions
predicted_approved = sum(y_pred == 1)
predicted_not_approved = sum(y_pred == 0)

print(f"Applications predicted as Approved: {predicted_approved}")
print(f"Applications predicted as Not Approved: {predicted_not_approved}\n")


plt.figure(figsize=(6, 4))
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Purples',
            xticklabels=['Not Approved', 'Approved'],
            yticklabels=['Not Approved', 'Approved'])
plt.title("Confusion Matrix - XGBoost")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 # Train XGBoost
#       5 model = XGBClassifier(eval_metric='logloss', random_state=42)
# ----> 6 model.fit(X_train, y_train)
#       8 # Predict
#       9 y_pred = model.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
#SVM
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Train SVM with the kernel rbf
svm_model = SVC(kernel='rbf', random_state=42)
svm_model.fit(X_train, y_train)

# Predict
y_pred = svm_model.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, y_pred) * 100
print(f"Accuracy (SVM): {acc:.2f}%")

# Confusion Matrix
cm_svm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:\n", cm_svm)

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, zero_division=0))

# Count predictions
predicted_approved = sum(y_pred == 1)
predicted_not_approved = sum(y_pred == 0)

print(f"Applications predicted as Approved: {predicted_approved}")
print(f"Applications predicted as Not Approved: {predicted_not_approved}\n")

# Plot the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Approved', 'Approved'],
            yticklabels=['Not Approved', 'Approved'])
plt.title("Confusion Matrix - SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       7 # Train SVM with the kernel rbf
#       8 svm_model = SVC(kernel='rbf', random_state=42)
# ----> 9 svm_model.fit(X_train, y_train)
#      11 # Predict
#      12 y_pred = svm_model.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
#SVM
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Train SVM with the kernel poly
svm_model = SVC(kernel='poly', random_state=42)
svm_model.fit(X_train, y_train)

# Predict
y_pred = svm_model.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, y_pred) * 100
print(f"Accuracy (SVM): {acc:.2f}%")

# Confusion Matrix
cm_svm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:\n", cm_svm)

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, zero_division=0))

# Count predictions
predicted_approved = sum(y_pred == 1)
predicted_not_approved = sum(y_pred == 0)

print(f"Applications predicted as Approved: {predicted_approved}")
print(f"Applications predicted as Not Approved: {predicted_not_approved}\n")

# Plot the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Approved', 'Approved'],
            yticklabels=['Not Approved', 'Approved'])
plt.title("Confusion Matrix - SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       7 # Train SVM with the kernel poly
#       8 svm_model = SVC(kernel='poly', random_state=42)
# ----> 9 svm_model.fit(X_train, y_train)
#      11 # Predict
#      12 y_pred = svm_model.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
#SVM
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Train SVM with the kernel rbf
svm_model = SVC(kernel='poly', random_state=42)
svm_model.fit(X_train, y_train)

# Predict
y_pred = svm_model.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, y_pred) * 100
print(f"Accuracy (SVM): {acc:.2f}%")

# Confusion Matrix
cm_svm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:\n", cm_svm)

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, zero_division=0))

# Count predictions
predicted_approved = sum(y_pred == 1)
predicted_not_approved = sum(y_pred == 0)

print(f"Applications predicted as Approved: {predicted_approved}")
print(f"Applications predicted as Not Approved: {predicted_not_approved}\n")

# Plot the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Approved', 'Approved'],
            yticklabels=['Not Approved', 'Approved'])
plt.title("Confusion Matrix - SVM")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
